# %%
from pathlib import Path
from itertools import islice, product
from pprint import pprint

import pandas as pd
import numpy as np
import numpy.typing as npt
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import display
import scopus.biblio_extractor as bex
import catk

np.set_printoptions(precision=4, suppress=True)
pd.set_option("display.float_format", lambda x: "{:.3f}".format(x))
pd.set_option("display.max_columns", 10)
pd.set_option("display.max_rows", 20)
pd.set_option("display.min_rows", 10)

# (11.7, 8.27) = A4 landscape
sns.set_theme(style="dark", palette="muted", font_scale=1.10, rc={"figure.figsize": (16.54, 11.7)})
# Out:
# '/home/romulus/Documents/unc-informatique.pharmaco-chemistry-biblio/catk/catk/data/data.py' loaded
# '/home/romulus/Documents/unc-informatique.pharmaco-chemistry-biblio/catk/catk/data/__init__.py' loaded
# '/home/romulus/Documents/unc-informatique.pharmaco-chemistry-biblio/catk/catk/ca.py' loaded
# '/home/romulus/Documents/unc-informatique.pharmaco-chemistry-biblio/catk/catk/__init__.py' loaded

# %%
activities_df = pd.read_csv("input/pharmaco_chemistry_2.csv", index_col=[0, 1], header=[0, 1]).fillna(0)
activities_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="5" halign="left">Abiotic</th>
#       <th>...</th>
#       <th colspan="2" halign="left">Pharmaco</th>
#       <th>Toxicity</th>
#       <th colspan="2" halign="left">Pharmaco</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>hydric stress/drought stress/hydric tolerance/drought tolerance/hydric resistance/drought resistance/hydric impact/drought impact/hydric change/drought change</th>
#       <th>heavy metal stress/metallic trace element stress/heavy metal tolerance/metallic trace element  tolerance/heavy metal resistance/metallic trace element  resistance/heavy metal impact/metallic trace element  impact/heavy metal change/metallic trace element  change</th>
#       <th>UV stress/light stress/UV tolerance/light tolerance/UV resistance/light resistance/UV impact/light impact/UV change/light change/irradiance</th>
#       <th>Salt stress/salinity stress/SALT tolerance/salinity tolerance/SALT resistance/salinity resistance/SALT impact/salinity impact/SALT change/salinity change</th>
#       <th>Heat stress/ Heat tolerance/Heat resistance/Heat impact/Heat change/temperature stress/ temperature tolerance/temperature resistance/temperature impact/temperature change</th>
#       <th>...</th>
#       <th>cytotoxicity</th>
#       <th>sedative/analgesic</th>
#       <th>toxicity</th>
#       <th>antioxidant</th>
#       <th>dementia/Alzheimer</th>
#     </tr>
#     <tr>
#       <th>alkaloid</th>
#       <th>acridine</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="5" valign="top">alkaloid</th>
#       <th>benzylamine</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>colchicine</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>cyclopeptide</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>imidazole</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>indole</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">terpenoid / terpene</th>
#       <th>tetraterpene/carotenoid/xanthophyll</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>triterpene/saponin</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>sterols</th>
#       <th>sterols/cardenolides</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>sulphur compounds</th>
#       <th>sulphur compounds/glucosinolates</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>lactones</th>
#       <th>lactones/strigolactones</th>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>...</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#   </tbody>
# </table>
# <p>54 rows × 37 columns</p>
# </div>

# %%
list(activities_df.columns)
# Out:
# [
#     (
#         'Abiotic',
#         'hydric stress/drought stress/hydric tolerance/drought tolerance/hydric resistance/drought resistance/hydric impact/drought impact/hydric change/drought change'
#     ),
#     (
#         'Abiotic',
#         'heavy metal stress/metallic trace element stress/heavy metal tolerance/metallic trace element  tolerance/heavy metal resistance/metallic trace element  resistance/heavy metal impact/metallic trace element  impact/heavy metal change/metallic trace element  change'
#     ),
#     (
#         'Abiotic',
#         'UV stress/light stress/UV tolerance/light tolerance/UV resistance/light resistance/UV impact/light impact/UV change/light change/irradiance'
#     ),
#     (
#         'Abiotic',
#         'Salt stress/salinity stress/SALT tolerance/salinity tolerance/SALT resistance/salinity resistance/SALT impact/salinity impact/SALT change/salinity change'
#     ),
#     (
#         'Abiotic',
#         'Heat stress/ Heat tolerance/Heat resistance/Heat impact/Heat change/temperature stress/ temperature tolerance/temperature resistance/temperature impact/temperature change'
#     ),
#     ('Abiotic', 'pH stress/ pH tolerance/pH resistance/pH impact/pH change'),
#     ('Biotic', 'antifeedant/phytophagous/herbivory/feeding\ndeterrents'),
#     ('Biotic', 'root respiration/branching factors/root formation'),
#     ('Biotic', 'attractant'),
#     ('Biotic', 'germination'),
#     ('Biotic', 'herbicidal'),
#     ('Biotic', 'pollination'),
#     ('Biotic', 'seed dispersal'),
#     ('Biotic', 'phytotoxicity'),
#     ('Biotic', 'quorum sensing'),
#     ('Biotic', 'repulsive'),
#     ('Biotic', 'pigment/colours'),
#     ('Pharmaco', 'immuno-modulatory'),
#     ('Pharmaco', 'antidiabetic'),
#     ('Pharmaco', 'cardiovascular'),
#     ('Pharmaco', 'obesity'),
#     ('Pharmaco', 'rheumatism'),
#     ('Pharmaco', 'antibacterial'),
#     ('Pharmaco', 'antifungal'),
#     ('Pharmaco', 'antimicrobial'),
#     ('Pharmaco', 'antiparasitic'),
#     ('Pharmaco', 'antiviral'),
#     ('Pharmaco', 'anti-inflammatory'),
#     ('Pharmaco', 'arthritis'),
#     ('Pharmaco', 'burns'),
#     ('Pharmaco', 'wound'),
#     ('Pharmaco', 'anticancer/anti-tumour/anti-apoptotic/anti-angiogenic'),
#     ('Pharmaco', 'cytotoxicity'),
#     ('Pharmaco', 'sedative/analgesic'),
#     ('Toxicity', 'toxicity'),
#     ('Pharmaco', 'antioxidant'),
#     ('Pharmaco', 'dementia/Alzheimer')
# ]
